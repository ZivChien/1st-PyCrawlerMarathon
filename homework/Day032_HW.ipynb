# %% [markdown]
# # 反爬：驗證碼處理
#
# * 了解「驗證碼機制」的反爬蟲機制
# * 「驗證碼機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import requests
import pytesseract
from PIL import Image
from io import BytesIO

# %%
import os

# %%
# !ls Day032_test
# Out:
# test1.png  test2.png

# %%
folder = 'Day032_test'

for f in os.listdir(folder):
    print(f)
    file = folder + "/" + f
    img = Image.open(file)
    display(img)
# Out:
# test1.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=954x362 at 0x7FA213715908>
# test2.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=154x64 at 0x7FA212EA6C50>

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？

# %%
for f in os.listdir(folder):
    s = pytesseract.image_to_string(img)
    print("%s -> %s" % (f, s))
    file = folder + "/" + f
    img = Image.open(file)
    display(img)
# Out:
# test1.png -> 1413
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=954x362 at 0x7FA212E45400>
# test2.png -> 619121
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=154x64 at 0x7FA212E45438>
