# %% [markdown]
# # 自動化更新機制
#
#
# * 如何定期執行爬蟲程式
# * 更新時需要注意的事情是什麼？

# %% [markdown]
# ## 作業目標
#
# * 列舉一個是需要用自動化更新的機制來達成的爬蟲應用。

# %% [markdown]
# > ANS:
# > * 時間敏感資訊，例如：股價，匯率
# > * 感測器資料,　例如：溫度，空氣品質
# > * 不斷滾動資料，例如：進出入人數，熱門留言數
