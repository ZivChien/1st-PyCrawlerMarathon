# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "網路爬蟲"  # 這裡可以自己定義有興趣的關鍵字

utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# 網路爬蟲: %E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2
# /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# 網路爬蟲（英語：web crawler），也叫網路蜘蛛（spider），是一種用來自動瀏覽全球資訊網的網路機器人。其目的一般為編纂網路索引（英語：Web indexing）。
#
# 網路搜尋引擎等站點通過爬蟲軟體更新自身的網站內容（英語：Web content）或其對其他網站的索引。網路爬蟲可以將自己所存取的頁面儲存下來，以便搜尋引擎事後生成索引（英語：Index (search engine)）供用戶搜尋。
#
# 爬蟲存取網站的過程會消耗目標系統資源。不少網路系統並不默許爬蟲工作。因此在存取大量頁面時，爬蟲需要考慮到規劃、負載，還需要講「禮貌」。 不願意被爬蟲存取、被爬蟲主人知曉的公開站點可以使用robots.txt檔案之類的方法避免存取。這個檔案可以要求機器人（英語：Software agent）只對網站的一部分進行索引，或完全不作處理。
#
# 網際網路上的頁面極多，即使是最大的爬蟲系統也無法做出完整的索引。因此在公元2000年之前的全球資訊網出現初期，搜尋引擎經常找不到多少相關結果。現在的搜尋引擎在這方面已經進步很多，能夠即刻給出高品質結果。
#
# 爬蟲還可以驗證超連結和HTML代碼，用於網路抓取（英語：Web scraping）（參見資料驅動編程（英語：Data-driven programming））。
#
# 網路爬蟲也可稱作網路蜘蛛[1]、螞蟻、自動索引程式（automatic indexer）[2] ，或（在FOAF（英語：FOAF (software)）軟體中）稱為網路疾走（web scutter）。[3]
#
# 網路爬蟲始於一張被稱作種子的統一資源位址（URL）列表。當網路爬蟲存取這些統一資源定位器時，它們會甄別出頁面上所有的超連結，並將它們寫入一張「待訪列表」，即所謂爬行疆域（英語：crawl frontier）。此疆域上的URL將會被按照一套策略迴圈來存取。如果爬蟲在執行的過程中複製歸檔和儲存網站上的資訊，這些檔案通常儲存，使他們可以較容易的被檢視。閱讀和瀏覽他們儲存的網站上並即時更新的資訊，這些被儲存的網頁又被稱為「快照」。越大容量的網頁意味著網路爬蟲只能在給予的時間內下載越少部分的網頁，所以要優先考慮其下載。高變化率意味著網頁可能已經被更新或者被取代。一些伺服器端軟體生成的URL（統一資源定位符）也使得網路爬蟲很難避免檢索到重複內容。
#
# 但是網際網路的資源卷帙浩繁，這也意味著網路爬蟲只能在一定時間內下載有限數量的網頁，因此它需要衡量優先順序的下載方式。有時候網頁出現、更新和消失的速度很快，也就是說網路爬蟲下載的網頁在幾秒後就已經被修改或甚至刪除了。這些都是網路爬蟲設計師們所面臨的兩個問題。
#
# 再者，伺服器端軟體所生成的統一資源位址數量龐大，以至網路爬蟲難免也會採集到重複的內容。根據超文字傳輸協定，無盡組合的參數所返回的頁面中，只有很少一部分確實傳回正確的內容。例如：數張快照陳列室的網站，可能通過幾個參數，讓用戶選擇相關快照：其一是通過四種方法對快照排序，其二是關於快照解析度的的三種選擇，其三是兩種檔案格式，另加一個用戶可否提供內容的選擇，這樣對於同樣的結果會有48種（4*3*2）不同的統一資源位址與其關聯。這種數學組合替網路爬蟲造成了麻煩，因為它們必須越過這些無關指令碼變化的組合，尋找不重複的內容。
#
# 爬蟲的實現由以下策略組成：[4]
#
# 爬蟲可能只想搜尋HTML頁面而避免其他MIME 類型。為了只請求HTML資源，爬蟲在抓取整個以GET方式請求的資源之前，通過建立HTTP的HEAD請求來決定網路資源的MIME類型。為了避免發出過多的請求，爬蟲會檢查URL和只請求那些以某些字元（如.html, .htm, .asp, .aspx, .php, .jsp, .jspx 或 / ）作為字尾的URL。這個策略可能會跳過很多HTML網路資源。
#
# 有些爬蟲還能避免請求一些帶有「?」的資源（動態生成）。為了避免掉入從網站下載無限量的URL的爬蟲陷阱。不過假若網站重寫URL以簡化URL的目的，這個策略就變得不可靠了。
#
# 爬蟲通常使用某些URL規格化的方式以避免資源的重複爬取。URL規格化，指的是以某種一致的方式修改和標準化URL的過程。這個過程有各種各樣的處理規則，包括統一轉換為小寫、移除「.」和「..」片段，以及在非空路徑里插入斜杆。
#
# 有些爬蟲希望從指定的網站中儘可能地爬取資源。而路徑上移爬蟲就是為了能爬取每個URL里提示出的每個路徑。[5] 例如，給定一個Http的種子URL: http://llama.org/hamster/monkey/page.html ，要爬取 /hamster/monkey/ ， /hamster/ 和 / 。Cothey發現路徑能非常有效地爬取獨立的資源，或以某種規律無法在站內部連結接爬取到的資源。
#
# 對於爬蟲來說，一個頁面的重要性也可以說是，給定查詢條件一個頁面相似效能起到的作用。網路爬蟲要下載相似的網頁被稱為主題爬蟲或局部爬蟲。這個主題爬蟲或局部爬蟲的概念第一次被Filippo Menczer[6][7] 和  Soumen Chakrabarti 等人提出的。[8]
#
# 網站的屬性之一就是經常動態變化，而爬取網站的一小部分往往需要花費幾個星期或者幾個月。等到網站爬蟲完成它的爬取，很多事件也已經發生了，包括增加、更新和刪除。
# 在搜尋引擎的角度，因為沒有檢測這些變化，會導致儲存了過期資源的代價。最常用的估價函式是新鮮度和過時性。
# 新鮮度：這是一個衡量抓取內容是不是準確的二元值。在時間t內，倉庫中頁面p的新鮮度是這樣定義的：
#
# 過時性:這是一個衡量本地已抓取的內容過時程度的指標。在時間t時，倉庫中頁面p的時效性的定義如下：
#
# 爬蟲相比於人，可以有更快的檢索速度和更深的層次，所以，他們可能使一個站點癱瘓。不需要說一個單獨的爬蟲一秒鐘要執行多條請求，下載大的檔案。一個伺服器也會很難回應多執行緒爬蟲的請求。
# 就像Koster所注意的那樣，爬蟲的使用對很多工作都是很有用的，但是對一般的社區，也需要付出代價。使用爬蟲的代價包括：[9]
#
# 對這些問題的局部解決方法是漫遊器排除協定（Robots exclusion protocol），也被稱為robots.txt議定書[10]，這份協定是讓管理員指明網路伺服器的不應該爬取的約定。這個標準沒有包括重新存取一台伺服器的間隔的建議，雖然設定存取間隔是避免伺服器超載的最有效辦法。最近的商業搜尋引擎，如Google，Ask Jeeves，MSN和Yahoo可以在robots.txt中使用一個額外的 「Crawl-delay」參數來指明請求之間的延遲。
#
# 一個並列爬蟲是並列執行多個行程的爬蟲。它的目標是最大化下載的速度，同時儘量減少並列的開銷和下載重複的頁面。為了避免下載一個頁面兩次，爬蟲系統需要策略來處理爬蟲執行時新發現的URL，因為同一個URL位址，可能被不同的爬蟲行程抓到。

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# 外部連結: [網路機器人] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA
# 外部連結: [網路] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [robots.txt] /wiki/Robots.txt
# 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# 外部連結: [HTML] /wiki/HTML
# 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
import os

def create_tmp(dir_path):
    if (not os.path.isdir(dir_path)):
        os.mkdir(dir_path)

# %%
def save_content(file, content):
    with open(file, "w", encoding="utf-8") as fh:
        print('[log] write ', file)
        for c in content:
            f = fh.write(c.get_text())

# %%
def search_link(content, link_dict):
    for ext_link in content:
        a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
        if len(a_tag) > 0:
            for link_string in a_tag:
                a_link = link_string["href"]       # 外部連結的網址
                a_keyword = link_string.get_text()  # 外部連結的中文名稱
                print("[log] 外部連結: [%s] %s" % (a_keyword, a_link))
                link_dict[a_link] = a_keyword

# %%
def WikiArticle(key_word_link, key_word, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
        tmp_dir = 'WikiArticl'
        file = file = tmp_dir+'/'+key_word+'.txt'
        create_tmp(tmp_dir)
        save_content(file, content)
        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        external_link_dict = dict({})
        search_link(content, external_link_dict)
        print("[log][%s] new ext: %s" %(recursive, len(external_link_dict)))
                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        if (len(external_link_dict) > 0):
            recursive = recursive + 1  # 遞迴深度加1
            for k, v in external_link_dict.items():
                WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 1

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2 (網路爬蟲)
# [log] write  WikiArticl/網路爬蟲.txt
# [log] 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# [log] 外部連結: [網路機器人] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA
# [log] 外部連結: [網路] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# [log] 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# [log] 外部連結: [robots.txt] /wiki/Robots.txt
# [log] 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# [log] 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# [log] 外部連結: [HTML] /wiki/HTML
# [log] 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# [log] 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# [log] 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# [log] 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A
# [log][0] new ext: 12
# 遞迴層[1] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# [log] write  WikiArticl/全球資訊網.txt
# [log] 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# [log] 外部連結: [超文字] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# [log] 外部連結: [CERN] /wiki/CERN
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [資訊時代] /wiki/%E8%B3%87%E8%A8%8A%E6%99%82%E4%BB%A3
# [log] 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# [log] 外部連結: [格式化] /wiki/%E6%A0%BC%E5%BC%8F%E5%8C%96%E6%96%87%E6%9C%AC
# [log] 外部連結: [超文件標示語言] /wiki/%E8%B6%85%E6%96%87%E4%BB%B6%E6%A8%99%E7%A4%BA%E8%AA%9E%E8%A8%80
# [log] 外部連結: [圖片] /wiki/%E5%9C%96%E7%89%87
# [log] 外部連結: [影片] /wiki/%E5%BD%B1%E7%89%87
# [log] 外部連結: [聲音] /wiki/%E8%81%B2%E9%9F%B3
# [log] 外部連結: [多媒體] /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94
# [log] 外部連結: [網際網路] /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# [log] 外部連結: [ENQUIRE] /wiki/ENQUIRE
# [log] 外部連結: [資料庫] /wiki/%E6%95%B0%E6%8D%AE%E5%BA%93
# [log] 外部連結: [語意網] /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91
# [log] 外部連結: [羅伯特·卡里奧] /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5
# [log] 外部連結: [NeXT] /wiki/NeXT
# [log] 外部連結: [聖誕節] /wiki/%E8%81%96%E8%AA%95%E7%AF%80
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [WorldWideWeb] /wiki/WorldWideWeb
# [log] 外部連結: [網頁伺服器] /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [新聞群組] /wiki/%E6%96%B0%E9%97%BB%E7%BB%84
# [log] 外部連結: [超文字] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC
# [log] 外部連結: [泰德·尼爾森] /wiki/%E6%B3%B0%E5%BE%B7%C2%B7%E5%B0%BC%E7%88%BE%E6%A3%AE
# [log] 外部連結: [道格拉斯·英格巴特] /wiki/%E9%81%93%E6%A0%BC%E6%8B%89%E6%96%AF%C2%B7%E8%8B%B1%E6%A0%BC%E5%B7%B4%E7%89%B9
# [log] 外部連結: [萬尼瓦爾·布希] /wiki/%E4%B8%87%E5%B0%BC%E7%93%A6%E5%B0%94%C2%B7%E5%B8%83%E4%BB%80
# [log] 外部連結: [微縮膠片] /wiki/%E5%BE%AE%E7%BC%A9%E8%83%B6%E7%89%87
# [log] 外部連結: [一千零一網] /wiki/%E4%B8%80%E5%8D%83%E9%9B%B6%E4%B8%80%E7%B6%B2%EF%BC%9A%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AFWWW%E7%99%BC%E6%98%8E%E4%BA%BA%E7%9A%84%E6%80%9D%E6%83%B3%E6%A7%8B%E5%9C%96
# [log] 外部連結: [HyperCard] /wiki/HyperCard
# [log] 外部連結: [歐洲核子研究組織] /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94
# [log] 外部連結: [Gopher] /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE)
# [log] 外部連結: [Unix] /wiki/Unix
# [log] 外部連結: [X Windows] /wiki/X_Windows
# [log] 外部連結: [ViolaWWW] /wiki/ViolaWWW
# [log] 外部連結: [Mosaic] /wiki/Mosaic
# [log] 外部連結: [伊利諾大學厄巴納-香檳分校] /wiki/%E4%BC%8A%E5%88%A9%E8%AB%BE%E5%A4%A7%E5%AD%B8%E5%8E%84%E5%B7%B4%E7%B4%8D-%E9%A6%99%E6%AA%B3%E5%88%86%E6%A0%A1
# [log] 外部連結: [國家超級電腦應用中心] /wiki/%E5%9B%BD%E5%AE%B6%E8%B6%85%E7%BA%A7%E7%94%B5%E8%84%91%E5%BA%94%E7%94%A8%E4%B8%AD%E5%BF%83
# [log] 外部連結: [馬克·安德森] /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E5%AE%89%E5%BE%B7%E6%A3%AE
# [log] 外部連結: [艾爾·高爾] /wiki/%E8%89%BE%E7%88%BE%C2%B7%E9%AB%98%E7%88%BE
# [log] 外部連結: [Gopher] /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE)
# [log] 外部連結: [全球資訊網協會] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F
# [log] 外部連結: [麻省理工學院] /wiki/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%A6%E9%99%A2
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# [log] 外部連結: [標記式語言] /wiki/%E6%A8%99%E8%A8%98%E5%BC%8F%E8%AA%9E%E8%A8%80
# [log] 外部連結: [語義網] /wiki/%E8%AA%9E%E7%BE%A9%E7%B6%B2
# [log] 外部連結: [同義詞] /wiki/%E5%90%8C%E4%B9%89%E8%AF%8D
# [log] 外部連結: [TCP/IP] /wiki/TCP/IP
# [log] 外部連結: [HTTP] /wiki/HTTP
# [log] 外部連結: [電腦網路] /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C
# [log] 外部連結: [HTTP] /wiki/HTTP
# [log] 外部連結: [HTTPS] /wiki/HTTPS
# [log] 外部連結: [統一資源定位符] /wiki/%E7%BB%9F%E4%B8%80%E8%B5%84%E6%BA%90%E5%AE%9A%E4%BD%8D%E7%AC%A6
# [log] 外部連結: [域名系統] /wiki/%E5%9F%9F%E5%90%8D%E7%B3%BB%E7%BB%9F
# [log] 外部連結: [IP位址] /wiki/IP%E5%9C%B0%E5%9D%80
# [log] 外部連結: [大眾傳媒] /wiki/%E5%A4%A7%E7%9C%BE%E5%82%B3%E5%AA%92
# [log] 外部連結: [出版商] /wiki/%E5%87%BA%E7%89%88%E5%95%86
# [log] 外部連結: [已開發國家] /wiki/%E5%8F%91%E8%BE%BE%E5%9B%BD%E5%AE%B6
# [log] 外部連結: [阿拉伯語] /wiki/%E9%98%BF%E6%8B%89%E4%BC%AF%E8%AF%AD
# [log] 外部連結: [希伯來語] /wiki/%E5%B8%8C%E4%BC%AF%E6%9D%A5%E8%AF%AD
# [log] 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# [log] 外部連結: [個人首頁] /wiki/%E4%B8%AA%E4%BA%BA%E4%B8%BB%E9%A1%B5
# [log] 外部連結: [JavaScript] /wiki/JavaScript
# [log] 外部連結: [ECMAScript] /wiki/ECMAScript
# [log] 外部連結: [網景通訊公司] /wiki/Netscape
# [log] 外部連結: [Java] /wiki/Java
# [log] 外部連結: [昇陽電腦公司] /wiki/%E6%98%87%E9%99%BD%E9%9B%BB%E8%85%A6
# [log] 外部連結: [C語言] /wiki/C%E8%AF%AD%E8%A8%80
# [log] 外部連結: [C++] /wiki/C%2B%2B
# [log] 外部連結: [物件導向的程式設計] /wiki/%E9%9D%A2%E5%90%91%E5%AF%B9%E8%B1%A1%E7%9A%84%E7%A8%8B%E5%BA%8F%E8%AE%BE%E8%AE%A1
# [log] 外部連結: [C++] /wiki/C%2B%2B
# [log] 外部連結: [文件物件模型] /wiki/%E6%96%87%E6%A1%A3%E5%AF%B9%E8%B1%A1%E6%A8%A1%E5%9E%8B
# [log] 外部連結: [DHTML] /wiki/DHTML
# [log] 外部連結: [駝峰式大小寫] /wiki/%E9%A7%9D%E5%B3%B0%E5%BC%8F%E5%A4%A7%E5%B0%8F%E5%AF%AB
# [log] 外部連結: [北美] /wiki/%E5%8C%97%E7%BE%8E
# [log] 外部連結: [李小文] /wiki/%E6%9D%8E%E5%B0%8F%E6%96%87
# [log] 外部連結: [中國科學院院士] /wiki/%E4%B8%AD%E5%9B%BD%E7%A7%91%E5%AD%A6%E9%99%A2%E9%99%A2%E5%A3%AB
# [log] 外部連結: [中國新聞電腦網路] /wiki/%E4%B8%AD%E5%9C%8B%E6%96%B0%E8%81%9E%E9%9B%BB%E8%85%A6%E7%B6%B2%E7%B5%A1
# [log] 外部連結: [華夏文摘] /wiki/%E8%8F%AF%E5%A4%8F%E6%96%87%E6%91%98
# [log] 外部連結: [漢語拼音] /wiki/%E6%BC%A2%E8%AA%9E%E6%8B%BC%E9%9F%B3
# [log] 外部連結: [標準] /wiki/%E6%A0%87%E5%87%86
# [log] 外部連結: [全球資訊網協會] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F
# [log] 外部連結: [深網] /wiki/%E6%B7%B1%E7%BD%91
# [log] 外部連結: [網頁] /wiki/%E7%BD%91%E9%A1%B5
# [log] 外部連結: [英語] /wiki/%E8%8B%B1%E8%AF%AD
# [log] 外部連結: [德語] /wiki/%E5%BE%B7%E8%AF%AD
# [log] 外部連結: [法語] /wiki/%E6%B3%95%E8%AF%AD
# [log] 外部連結: [日語] /wiki/%E6%97%A5%E8%AF%AD
# [log] 外部連結: [中文] /wiki/%E4%B8%AD%E6%96%87
# [log] 外部連結: [語言] /wiki/%E8%AF%AD%E8%A8%80
# [log] 外部連結: [網際網路] /wiki/%E5%9B%A0%E7%89%B9%E7%BD%91
# [log] 外部連結: [點對點技術] /wiki/%E9%BB%9E%E5%B0%8D%E9%BB%9E%E6%8A%80%E8%A1%93
# [log] 外部連結: [服務品質] /wiki/QoS
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [Google doodle] /wiki/Google_doodle
# [log][1] new ext: 89
# 遞迴層[1] - /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA (網路機器人)
# [log] write  WikiArticl/網路機器人.txt
# [log] 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# [log] 外部連結: [軟體] /wiki/%E8%BD%AF%E4%BB%B6
# [log] 外部連結: [指令碼] /wiki/%E8%84%9A%E6%9C%AC%E8%AF%AD%E8%A8%80
# [log] 外部連結: [網路爬蟲機器人] /wiki/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB
# [log] 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# [log] 外部連結: [robots.txt] /wiki/Robots.txt
# [log] 外部連結: [驗證碼] /wiki/%E9%AA%8C%E8%AF%81%E7%A0%81
# [log][1] new ext: 7
# 遞迴層[1] - /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E (網路)
# [log] write  WikiArticl/網路.txt
# [log] 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# [log] 外部連結: [搜尋結果頁] /wiki/%E6%90%9C%E7%B4%A2%E7%BB%93%E6%9E%9C%E9%A1%B5
# [log] 外部連結: [網路爬蟲] /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2
# [log] 外部連結: [深網] /wiki/%E6%B7%B1%E7%BD%91
# [log] 外部連結: [文字資訊檢索] /wiki/%E6%96%87%E6%9C%AC%E4%BF%A1%E6%81%AF%E6%A3%80%E7%B4%A2
# [log] 外部連結: [全球資訊網] /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2
# [log] 外部連結: [Gopher] /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE)
# [log] 外部連結: [HTTP] /wiki/HTTP
# [log] 外部連結: [web] /wiki/Web
# [log] 外部連結: [Telnet] /wiki/Telnet
# [log] 外部連結: [Yahoo] /wiki/Yahoo
# [log] 外部連結: [Lycos] /wiki/Lycos
# [log] 外部連結: [蕃薯藤] /wiki/%E8%95%83%E8%96%AF%E8%97%A4
# [log] 外部連結: [台灣] /wiki/%E5%8F%B0%E7%81%A3
# [log] 外部連結: [華盛頓大學] /wiki/%E8%8F%AF%E7%9B%9B%E9%A0%93%E5%A4%A7%E5%AD%B8
# [log] 外部連結: [AltaVista] /wiki/AltaVista
# [log] 外部連結: [新聞群組] /wiki/%E6%96%B0%E9%97%BB%E7%BB%84
# [log] 外部連結: [PChome] /wiki/PChome_Online%E7%B6%B2%E8%B7%AF%E5%AE%B6%E5%BA%AD
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [pdf] /wiki/Pdf
# [log] 外部連結: [MP3] /wiki/MP3
# [log] 外部連結: [FTP] /wiki/FTP
# [log] 外部連結: [搜狐公司] /wiki/%E6%90%9C%E7%8B%90
# [log] 外部連結: [台灣中正大學] /wiki/%E4%B8%AD%E6%AD%A3%E5%A4%A7%E5%AD%B8
# [log] 外部連結: [百度] /wiki/%E7%99%BE%E5%BA%A6
# [log] 外部連結: [adware] /wiki/Adware
# [log] 外部連結: [spyware] /wiki/Spyware
# [log] 外部連結: [流氓軟體] /wiki/%E6%B5%81%E6%B0%93%E8%BB%9F%E4%BB%B6
# [log] 外部連結: [Yahoo] /wiki/Yahoo
# [log] 外部連結: [3721] /wiki/3721
# [log] 外部連結: [阿里巴巴] /wiki/%E9%98%BF%E9%87%8C%E5%B7%B4%E5%B7%B4
# [log] 外部連結: [Yahoo] /wiki/Yahoo
# [log] 外部連結: [雅虎中國] /wiki/%E9%9B%85%E8%99%8E%E4%B8%AD%E5%9B%BD
# [log] 外部連結: [搜狗] /wiki/%E6%90%9C%E7%8B%97
# [log] 外部連結: [微軟] /wiki/%E5%BE%AE%E8%BB%9F
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [網易] /wiki/%E7%B6%B2%E6%98%93
# [log] 外部連結: [有道] /wiki/%E6%9C%89%E9%81%93
# [log] 外部連結: [六四事件] /wiki/%E5%85%AD%E5%9B%9B%E4%BA%8B%E4%BB%B6
# [log] 外部連結: [防火長城] /wiki/%E9%98%B2%E7%81%AB%E9%95%B7%E5%9F%8E
# [log] 外部連結: [微軟學術搜尋] /wiki/%E5%BE%AE%E8%BB%9F%E5%AD%B8%E8%A1%93%E6%90%9C%E7%B4%A2
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [Yandex] /wiki/Yandex
# [log] 外部連結: [Naver] /wiki/NAVER
# [log][1] new ext: 40
# 遞迴層[1] - /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E (搜尋引擎)
# [log] write  WikiArticl/搜尋引擎.txt
# [log] 外部連結: [資訊檢索系統] /wiki/%E4%BF%A1%E6%81%AF%E6%AA%A2%E7%B4%A2
# [log] 外部連結: [電腦系統] /wiki/%E9%9B%BB%E5%AD%90%E8%A8%88%E7%AE%97%E6%A9%9F
# [log] 外部連結: [網路搜尋引擎] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# [log] 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# [log] 外部連結: [專案] /wiki/%E9%A1%B9%E7%9B%AE
# [log] 外部連結: [介面] /wiki/%E6%8E%A5%E5%8F%A3
# [log] 外部連結: [索引] /wiki/%E7%B4%A2%E5%BC%95
# [log] 外部連結: [相關性] /wiki/%E7%9B%B8%E5%85%B3
# [log][1] new ext: 8
# 遞迴層[1] - /wiki/Robots.txt (robots.txt)
# [log] write  WikiArticl/robots.txt.txt
# [log] 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# [log] 外部連結: [ASCII] /wiki/ASCII
# [log] 外部連結: [文字檔案] /wiki/%E6%96%87%E6%9C%AC%E6%96%87%E4%BB%B6
# [log] 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# [log] 外部連結: [網路蜘蛛] /wiki/%E7%BD%91%E7%BB%9C%E8%9C%98%E8%9B%9B
# [log] 外部連結: [元資料] /wiki/%E5%85%83%E6%95%B0%E6%8D%AE
# [log] 外部連結: [URL] /wiki/URL
# [log] 外部連結: [元資料] /wiki/%E5%85%83%E6%95%B0%E6%8D%AE
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [Yahoo] /wiki/Yahoo
# [log] 外部連結: [Bing] /wiki/Bing
# [log] 外部連結: [Ask] /wiki/Ask.com
# [log][1] new ext: 11
# 遞迴層[1] - /wiki/%E7%BD%91%E7%AB%99 (網站)
# [log] write  WikiArticl/網站.txt
# [log] 外部連結: [全球資訊網] /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2
# [log] 外部連結: [HTML] /wiki/HTML
# [log] 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# [log] 外部連結: [網路服務] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%8D%E5%8A%A1
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [招聘] /wiki/%E6%8B%9B%E8%81%98
# [log] 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# [log] 外部連結: [個人主頁] /wiki/%E5%80%8B%E4%BA%BA%E4%B8%BB%E9%A0%81
# [log] 外部連結: [新聞] /wiki/%E6%96%B0%E8%81%9E
# [log] 外部連結: [旅遊] /wiki/%E6%97%85%E9%81%8A
# [log] 外部連結: [娛樂] /wiki/%E5%A8%9B%E6%A8%82
# [log] 外部連結: [經濟] /wiki/%E7%B6%93%E6%BF%9F
# [log] 外部連結: [圖像] /wiki/%E5%9C%96%E5%83%8F
# [log] 外部連結: [聲音] /wiki/%E8%81%B2%E9%9F%B3
# [log] 外部連結: [動畫] /wiki/%E5%8B%95%E7%95%AB
# [log] 外部連結: [影片] /wiki/%E5%BD%B1%E7%89%87
# [log] 外部連結: [3D] /wiki/3D
# [log] 外部連結: [動態網頁] /wiki/%E5%8B%95%E6%85%8B%E7%B6%B2%E9%A0%81
# [log] 外部連結: [電子郵件] /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6
# [log] 外部連結: [全球資訊網] /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# [log] 外部連結: [CERN] /wiki/CERN
# [log] 外部連結: [個人網站] /wiki/%E5%80%8B%E4%BA%BA%E7%B6%B2%E7%AB%99
# [log] 外部連結: [政府網站] /wiki/%E7%94%B5%E5%AD%90%E6%94%BF%E5%8A%A1
# [log] 外部連結: [非營利組織] /wiki/%E9%9D%9E%E7%87%9F%E5%88%A9%E7%B5%84%E7%B9%94
# [log] 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# [log] 外部連結: [超文件標示語言] /wiki/%E8%B6%85%E6%96%87%E4%BB%B6%E6%A8%99%E7%A4%BA%E8%AA%9E%E8%A8%80
# [log] 外部連結: [使用者代理] /wiki/%E4%BD%BF%E7%94%A8%E8%80%85%E4%BB%A3%E7%90%86
# [log] 外部連結: [軟體] /wiki/%E8%BB%9F%E9%AB%94
# [log] 外部連結: [電腦] /wiki/%E9%9B%BB%E8%85%A6
# [log] 外部連結: [筆記型電腦] /wiki/%E7%AD%86%E8%A8%98%E5%9E%8B%E9%9B%BB%E8%85%A6
# [log] 外部連結: [代管] /wiki/%E7%B6%B2%E9%A0%81%E5%AF%84%E5%AD%98%E6%9C%8D%E5%8B%99
# [log] 外部連結: [網頁伺服器] /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [HTTP] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A
# [log] 外部連結: [Apache] /wiki/Apache
# [log] 外部連結: [微軟] /wiki/%E5%BE%AE%E8%BB%9F
# [log] 外部連結: [IIS] /wiki/IIS
# [log] 外部連結: [Nginx] /wiki/Nginx
# [log] 外部連結: [Lighttpd] /wiki/Lighttpd
# [log] 外部連結: [Cherokee] /wiki/Cherokee_(Web%E6%9C%8D%E5%8A%A1%E5%99%A8)
# [log][1] new ext: 38
# 遞迴層[1] - /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 (超連結)
# [log] write  WikiArticl/超連結.txt
# [log] 外部連結: [超文字] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC
# [log] 外部連結: [論文] /wiki/%E8%AB%96%E6%96%87
# [log] 外部連結: [全球資訊網] /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2
# [log] 外部連結: [URL] /wiki/URL
# [log] 外部連結: [瀏覽器] /wiki/%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [外掛程式] /wiki/%E6%8F%92%E4%BB%B6
# [log][1] new ext: 6
# 遞迴層[1] - /wiki/HTML (HTML)
# [log] write  WikiArticl/HTML.txt
# [log] 外部連結: [網頁] /wiki/%E7%BD%91%E9%A1%B5
# [log] 外部連結: [標記語言] /wiki/%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80
# [log] 外部連結: [CSS] /wiki/CSS
# [log] 外部連結: [JavaScript] /wiki/JavaScript
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8
# [log] 外部連結: [程式語言] /wiki/%E7%BC%96%E7%A8%8B%E8%AF%AD%E8%A8%80
# [log] 外部連結: [HTML元素] /wiki/HTML%E5%85%83%E7%B4%A0
# [log] 外部連結: [語意] /wiki/%E8%AF%AD%E4%B9%89
# [log] 外部連結: [尖括號] /wiki/%E6%8B%AC%E5%8F%B7
# [log] 外部連結: [JavaScript] /wiki/JavaScript
# [log] 外部連結: [手稿語言] /wiki/%E8%84%9A%E6%9C%AC%E8%AF%AD%E8%A8%80
# [log] 外部連結: [階層式樣式表] /wiki/%E5%B1%82%E5%8F%A0%E6%A0%B7%E5%BC%8F%E8%A1%A8
# [log] 外部連結: [全球資訊網協會] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# [log] 外部連結: [歐洲核子研究中心] /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94
# [log] 外部連結: [ENQUIRE] /wiki/ENQUIRE
# [log] 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# [log] 外部連結: [超文字] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC
# [log] 外部連結: [羅伯特·卡里奧] /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5
# [log] 外部連結: [標準通用標記語言] /wiki/SGML
# [log] 外部連結: [網際網路工程任務組] /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%B7%A5%E7%A8%8B%E4%BB%BB%E5%8A%A1%E7%BB%84
# [log] 外部連結: [文件類型定義] /wiki/%E6%96%87%E4%BB%B6%E7%B1%BB%E5%9E%8B%E6%8F%8F%E8%BF%B0
# [log] 外部連結: [NCSA Mosaic] /wiki/NCSA_Mosaic
# [log] 外部連結: [全球資訊網協會] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F
# [log] 外部連結: [ISO] /wiki/%E5%9C%8B%E9%9A%9B%E6%A8%99%E6%BA%96%E5%8C%96%E7%B5%84%E7%B9%94
# [log] 外部連結: [IEC] /wiki/IEC
# [log] 外部連結: [網頁超文字應用技術工作小組] /wiki/%E7%B6%B2%E9%A0%81%E8%B6%85%E6%96%87%E6%9C%AC%E6%8A%80%E8%A1%93%E5%B7%A5%E4%BD%9C%E5%B0%8F%E7%B5%84
# [log] 外部連結: [XML] /wiki/XML
# [log] 外部連結: [標準模式] /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F
# [log] 外部連結: [Hello World] /wiki/Hello_World
# [log] 外部連結: [怪異模式] /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F
# [log] 外部連結: [換行] /wiki/%E6%8F%9B%E8%A1%8C
# [log] 外部連結: [阿拉伯語] /wiki/%E9%98%BF%E6%8B%89%E4%BC%AF%E8%AF%AD
# [log] 外部連結: [波斯語] /wiki/%E6%B3%A2%E6%96%AF%E8%AF%AD
# [log] 外部連結: [希伯來語] /wiki/%E5%B8%8C%E4%BC%AF%E6%9D%A5%E8%AF%AD
# [log] 外部連結: [字元值參考] /wiki/%E5%AD%97%E5%85%83%E5%80%BC%E5%8F%83%E8%80%83
# [log] 外部連結: [用戶代理] /wiki/%E7%94%A8%E6%88%B7%E4%BB%A3%E7%90%86
# [log] 外部連結: [搜尋和索引] /wiki/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB
# [log] 外部連結: [字元編碼] /wiki/%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81
# [log] 外部連結: [UTF-8] /wiki/UTF-8
# [log] 外部連結: [Unicode] /wiki/Unicode
# [log] 外部連結: [資料類型] /wiki/%E6%95%B8%E6%93%9A%E9%A1%9E%E5%9E%8B
# [log] 外部連結: [怪異模式] /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F
# [log] 外部連結: [文件類型定義] /wiki/%E6%96%87%E6%A1%A3%E7%B1%BB%E5%9E%8B%E5%AE%9A%E4%B9%89
# [log] 外部連結: [HTML5] /wiki/HTML5
# [log] 外部連結: [怪異模式] /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F
# [log] 外部連結: [span與div] /wiki/Span_and_div
# [log] 外部連結: [CSS] /wiki/%E5%B1%82%E5%8F%A0%E6%A0%B7%E5%BC%8F%E8%A1%A8
# [log] 外部連結: [呈現與內容分離] /wiki/%E5%91%88%E7%8E%B0%E4%B8%8E%E5%86%85%E5%AE%B9%E5%88%86%E7%A6%BB
# [log] 外部連結: [語意網] /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# [log] 外部連結: [Web 2.0] /wiki/Web_2.0
# [log] 外部連結: [混搭] /wiki/%E6%B7%B7%E6%90%AD_(%E4%BA%92%E8%81%AF%E7%B6%B2)
# [log] 外部連結: [價格比較網站] /wiki/%E6%A0%BC%E5%83%B9
# [log] 外部連結: [聚合] /wiki/%E8%81%9A%E5%90%88%E5%99%A8
# [log] 外部連結: [網頁開發者] /wiki/%E7%B6%B2%E9%A0%81%E9%96%8B%E7%99%BC%E8%80%85
# [log] 外部連結: [API] /wiki/API
# [log] 外部連結: [網路爬蟲] /wiki/%E7%B6%B2%E8%B7%AF%E8%9C%98%E8%9B%9B
# [log] 外部連結: [演算法] /wiki/%E7%AE%97%E6%B3%95
# [log] 外部連結: [搜尋工具] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# [log] 外部連結: [網頁伺服器] /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [電子郵件] /wiki/%E7%94%B5%E5%AD%90%E9%82%AE%E4%BB%B6
# [log] 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# [log] 外部連結: [HTTP] /wiki/HTTP
# [log] 外部連結: [檔案類型] /wiki/%E6%96%87%E4%BB%B6%E9%A1%9E%E5%9E%8B
# [log] 外部連結: [元資料] /wiki/%E5%85%83%E6%95%B0%E6%8D%AE
# [log] 外部連結: [MIME] /wiki/MIME
# [log] 外部連結: [HTML字元編碼] /wiki/HTML%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81
# [log] 外部連結: [XML] /wiki/XML
# [log] 外部連結: [語法錯誤] /wiki/%E8%AF%AD%E6%B3%95%E9%94%99%E8%AF%AF
# [log] 外部連結: [純文字] /wiki/%E7%BA%AF%E6%96%87%E6%9C%AC
# [log] 外部連結: [語意] /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91
# [log] 外部連結: [圖形化使用者介面] /wiki/%E5%9B%BE%E5%BD%A2%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2
# [log] 外部連結: [釣魚攻擊] /wiki/%E9%92%93%E9%B1%BC%E5%BC%8F%E6%94%BB%E5%87%BB
# [log] 外部連結: [垃圾郵件] /wiki/%E5%9E%83%E5%9C%BE%E9%9B%BB%E9%83%B5
# [log] 外部連結: [副檔名] /wiki/%E6%96%87%E4%BB%B6%E6%89%A9%E5%B1%95%E5%90%8D
# [log] 外部連結: [DOS] /wiki/DOS
# [log] 外部連結: [FAT] /wiki/FAT
# [log] 外部連結: [3個字母] /wiki/8.3
# [log] 外部連結: [Microsoft Windows] /wiki/Microsoft_Windows
# [log] 外部連結: [Cookie] /wiki/Cookie
# [log] 外部連結: [登錄檔] /wiki/%E6%B3%A8%E5%86%8C%E8%A1%A8
# [log] 外部連結: [EXE檔案] /wiki/EXE%E6%A0%BC%E5%BC%8F
# [log] 外部連結: [所見即所得] /wiki/%E6%89%80%E8%A6%8B%E5%8D%B3%E6%89%80%E5%BE%97
# [log] 外部連結: [圖形化使用者介面] /wiki/%E5%9B%BE%E5%BD%A2%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2
# [log] 外部連結: [文書處理器] /wiki/%E6%96%87%E5%AD%97%E5%A4%84%E7%90%86%E5%99%A8
# [log] 外部連結: [WYSIWYM] /wiki/WYSIWYM
# [log][1] new ext: 78
# 遞迴層[1] - /wiki/%E7%B6%B2%E9%A0%81 (網頁)
# [log] write  WikiArticl/網頁.txt
# [log] 外部連結: [全球資訊網] /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [電腦] /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA
# [log] 外部連結: [電腦] /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA
# [log] 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# [log] 外部連結: [網址] /wiki/%E7%B6%B2%E5%9D%80
# [log] 外部連結: [URL] /wiki/URL
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8
# [log] 外部連結: [HTML] /wiki/HTML
# [log] 外部連結: [圖像] /wiki/%E5%9C%96%E5%83%8F
# [log] 外部連結: [網站] /wiki/%E7%B6%B2%E7%AB%99
# [log] 外部連結: [首頁] /wiki/%E9%A6%96%E9%A0%81
# [log] 外部連結: [文字編輯器] /wiki/%E6%96%87%E5%AD%97%E7%B7%A8%E8%BC%AF%E5%99%A8
# [log] 外部連結: [HTML編輯器] /wiki/HTML%E7%B7%A8%E8%BC%AF%E5%99%A8
# [log] 外部連結: [全球資訊網] /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2
# [log] 外部連結: [FTP] /wiki/FTP
# [log] 外部連結: [上傳] /wiki/%E4%B8%8A%E8%BC%89
# [log][1] new ext: 15
# 遞迴層[1] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# [log] write  WikiArticl/網際網路.txt
# [log] 外部連結: [20世紀] /wiki/20%E4%B8%96%E7%B4%80
# [log] 外部連結: [電腦網路] /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C
# [log] 外部連結: [網路] /wiki/%E7%B6%B2%E8%B7%AF
# [log] 外部連結: [網路協定] /wiki/%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [學術界] /wiki/%E5%AD%B8%E8%A1%93%E7%95%8C
# [log] 外部連結: [電子] /wiki/%E7%94%B5%E5%AD%90%E6%8A%80%E6%9C%AF
# [log] 外部連結: [無線] /wiki/%E7%84%A1%E7%B7%9A
# [log] 外部連結: [光纖網路技術] /wiki/%E5%85%89%E7%BA%96%E7%B6%B2%E8%B7%AF
# [log] 外部連結: [超文字] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC
# [log] 外部連結: [全球資訊網] /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2
# [log] 外部連結: [電子郵件] /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6
# [log] 外部連結: [通話] /wiki/%E7%B6%B2%E9%9A%9B%E5%8D%94%E8%AD%B0%E9%80%9A%E8%A9%B1%E6%8A%80%E8%A1%93
# [log] 外部連結: [檔案分享] /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB
# [log] 外部連結: [美國聯邦政府] /wiki/%E7%BE%8E%E5%9C%8B%E8%81%AF%E9%82%A6%E6%94%BF%E5%BA%9C
# [log] 外部連結: [ARPANET] /wiki/ARPANET
# [log] 外部連結: [TCP/IP] /wiki/TCP/IP
# [log] 外部連結: [分散網路] /wiki/%E5%88%86%E6%95%A3%E7%BD%91%E7%BB%9C
# [log] 外部連結: [排隊論] /wiki/%E6%8E%92%E9%98%9F%E8%AE%BA
# [log] 外部連結: [封包交換] /wiki/%E5%B0%81%E5%8C%85%E4%BA%A4%E6%8F%9B
# [log] 外部連結: [美國國防部] /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8
# [log] 外部連結: [高等研究計劃署] /wiki/%E5%9C%8B%E9%98%B2%E9%AB%98%E7%AD%89%E7%A0%94%E7%A9%B6%E8%A8%88%E5%8A%83%E7%BD%B2
# [log] 外部連結: [冷戰] /wiki/%E5%86%B7%E6%88%98
# [log] 外部連結: [ARPANET] /wiki/ARPANET
# [log] 外部連結: [倫納德·克萊因羅克] /wiki/%E4%BC%A6%E7%BA%B3%E5%BE%B7%C2%B7%E5%85%8B%E8%8E%B1%E5%9B%A0%E7%BD%97%E5%85%8B
# [log] 外部連結: [加利福尼亞大學洛杉磯分校] /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9E%E5%A4%A7%E5%AD%B8%E6%B4%9B%E6%9D%89%E7%A3%AF%E5%88%86%E6%A0%A1
# [log] 外部連結: [加利福尼亞州門羅帕克] /wiki/%E9%97%A8%E6%B4%9B%E5%B8%95%E5%85%8B_(%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9A%E5%B7%9E)
# [log] 外部連結: [道格拉斯·恩格爾巴特] /wiki/%E9%81%93%E6%A0%BC%E6%8B%89%E6%96%AF%C2%B7%E6%81%A9%E6%A0%BC%E5%B0%94%E5%B7%B4%E7%89%B9
# [log] 外部連結: [加利福尼亞大學聖塔芭芭拉分校] /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9E%E5%A4%A7%E5%AD%B8%E8%81%96%E5%A1%94%E8%8A%AD%E8%8A%AD%E6%8B%89%E5%88%86%E6%A0%A1
# [log] 外部連結: [猶他大學] /wiki/%E7%8A%B9%E4%BB%96%E5%A4%A7%E5%AD%A6
# [log] 外部連結: [羅伯特·卡恩] /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E6%81%A9
# [log] 外部連結: [文頓·瑟夫] /wiki/%E6%96%87%E9%A0%93%C2%B7%E7%91%9F%E5%A4%AB
# [log] 外部連結: [TCP/IP] /wiki/TCP/IP
# [log] 外部連結: [圖靈獎] /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96
# [log] 外部連結: [美國國家科學基金會] /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E5%9F%BA%E9%87%91%E4%BC%9A
# [log] 外部連結: [超級電腦] /wiki/%E8%B6%85%E7%B4%9A%E9%9B%BB%E8%85%A6
# [log] 外部連結: [網際網路服務提供商] /wiki/%E4%BA%92%E8%81%AF%E7%B6%B2%E6%9C%8D%E5%8B%99%E6%8F%90%E4%BE%9B%E5%95%86
# [log] 外部連結: [CompuServe] /wiki/CompuServe
# [log] 外部連結: [康奈爾大學] /wiki/%E5%BA%B7%E5%A5%88%E5%B0%94%E5%A4%A7%E5%AD%A6
# [log] 外部連結: [歐洲核子研究中心] /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E4%B8%AD%E5%BF%83
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# [log] 外部連結: [第一個網頁瀏覽器] /wiki/WorldWideWeb
# [log] 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# [log] 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A
# [log] 外部連結: [超文字標記語言] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [網頁伺服器] /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [網站] /wiki/%E7%B6%B2%E7%AB%99
# [log] 外部連結: [ARPANET] /wiki/ARPANET
# [log] 外部連結: [美聯社] /wiki/%E7%BE%8E%E8%81%94%E7%A4%BE
# [log] 外部連結: [web] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# [log] 外部連結: [紐約時報] /wiki/%E7%BA%BD%E7%BA%A6%E6%97%B6%E6%8A%A5
# [log] 外部連結: [電話撥號] /wiki/%E6%92%A5%E8%99%9F%E9%80%A3%E7%B7%9A
# [log] 外部連結: [網際網路協定] /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF%E5%8D%94%E5%AE%9A
# [log] 外部連結: [IPv4] /wiki/IPv4
# [log] 外部連結: [IP位址] /wiki/IP%E5%9C%B0%E5%9D%80
# [log] 外部連結: [IPv6] /wiki/IPv6
# [log] 外部連結: [UDP協定] /wiki/%E7%94%A8%E6%88%B7%E6%95%B0%E6%8D%AE%E6%8A%A5%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [TCP協定] /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [UDP] /wiki/UDP
# [log] 外部連結: [FTP] /wiki/%E6%96%87%E4%BB%B6%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [HTTP] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [全球資訊網] /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2
# [log] 外部連結: [社群媒體] /wiki/%E7%A4%BE%E7%BE%A4%E5%AA%92%E9%AB%94
# [log] 外部連結: [電子郵件] /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6
# [log] 外部連結: [行動應用程式] /wiki/%E8%A1%8C%E5%8B%95%E6%87%89%E7%94%A8%E7%A8%8B%E5%BC%8F
# [log] 外部連結: [多人電子遊戲] /wiki/%E5%A4%9A%E4%BA%BA%E7%94%B5%E5%AD%90%E6%B8%B8%E6%88%8F
# [log] 外部連結: [網際網路通話] /wiki/VoIP
# [log] 外部連結: [檔案分享] /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB
# [log] 外部連結: [串流媒體] /wiki/%E4%B8%B2%E6%B5%81%E5%AA%92%E9%AB%94
# [log] 外部連結: [伺服器] /wiki/%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [資料中心] /wiki/%E8%B3%87%E6%96%99%E4%B8%AD%E5%BF%83
# [log] 外部連結: [內容傳遞網路] /wiki/%E5%85%A7%E5%AE%B9%E5%82%B3%E9%81%9E%E7%B6%B2%E8%B7%AF
# [log] 外部連結: [全球資訊網] /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2
# [log] 外部連結: [檔案] /wiki/%E9%9B%BB%E8%85%A6%E6%AA%94%E6%A1%88
# [log] 外部連結: [圖片] /wiki/%E5%9C%96%E7%89%87
# [log] 外部連結: [多媒體] /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94
# [log] 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# [log] 外部連結: [統一資源標誌符] /wiki/%E7%B5%B1%E4%B8%80%E8%B3%87%E6%BA%90%E6%A8%99%E8%AA%8C%E7%AC%A6
# [log] 外部連結: [網頁伺服器] /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E8%AD%B0
# [log] 外部連結: [微軟] /wiki/%E5%BE%AE%E8%BB%9F
# [log] 外部連結: [Internet Explorer] /wiki/Internet_Explorer
# [log] 外部連結: [Edge] /wiki/Microsoft_Edge
# [log] 外部連結: [Mozilla Firefox] /wiki/Mozilla_Firefox
# [log] 外部連結: [Opera] /wiki/Opera%E9%9B%BB%E8%85%A6%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [蘋果公司] /wiki/%E8%98%8B%E6%9E%9C%E5%85%AC%E5%8F%B8
# [log] 外部連結: [Safari] /wiki/Safari
# [log] 外部連結: [Google Chrome] /wiki/Google_Chrome
# [log] 外部連結: [多媒體] /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94
# [log] 外部連結: [遊戲] /wiki/%E7%BD%91%E9%A1%B5%E6%B8%B8%E6%88%8F
# [log] 外部連結: [Yahoo] /wiki/Yahoo
# [log] 外部連結: [Bing] /wiki/Bing
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E5%B0%8B%E5%BC%95%E6%93%8E
# [log] 外部連結: [關鍵字] /wiki/%E9%97%9C%E9%8D%B5%E5%AD%97
# [log] 外部連結: [電子郵件] /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6
# [log] 外部連結: [電子郵件位址] /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6%E5%9C%B0%E5%9D%80
# [log] 外部連結: [檔案分享] /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB
# [log] 外部連結: [檔案傳輸協定] /wiki/%E6%AA%94%E6%A1%88%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A
# [log] 外部連結: [檔案伺服器] /wiki/%E6%AA%94%E6%A1%88%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [惡意軟體] /wiki/%E6%83%A1%E6%84%8F%E8%BB%9F%E9%AB%94
# [log] 外部連結: [電腦病毒] /wiki/%E9%9B%BB%E8%85%A6%E7%97%85%E6%AF%92
# [log] 外部連結: [電腦蠕蟲] /wiki/%E9%9B%BB%E8%85%A6%E8%A0%95%E8%9F%B2
# [log] 外部連結: [阻斷服務攻擊] /wiki/%E9%98%BB%E6%96%B7%E6%9C%8D%E5%8B%99%E6%94%BB%E6%93%8A
# [log] 外部連結: [勒索軟體] /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94
# [log] 外部連結: [殭屍網路] /wiki/%E6%AE%AD%E5%B1%8D%E7%B6%B2%E7%B5%A1
# [log] 外部連結: [間諜軟體] /wiki/%E9%96%93%E8%AB%9C%E8%BB%9F%E4%BB%B6
# [log] 外部連結: [網路犯罪] /wiki/%E7%94%B5%E8%84%91%E7%8A%AF%E7%BD%AA
# [log] 外部連結: [美國國家安全域] /wiki/%E7%BE%8E%E5%9C%8B%E5%9C%8B%E5%AE%B6%E5%AE%89%E5%85%A8%E5%B1%80
# [log] 外部連結: [中情局] /wiki/%E4%B8%AD%E6%83%85%E5%B1%80
# [log] 外部連結: [史諾登] /wiki/%E7%88%B1%E5%BE%B7%E5%8D%8E%C2%B7%E6%96%AF%E8%AF%BA%E7%99%BB
# [log] 外部連結: [衛報] /wiki/%E8%A1%9B%E5%A0%B1
# [log] 外部連結: [華盛頓郵報] /wiki/%E8%8F%AF%E7%9B%9B%E9%A0%93%E9%83%B5%E5%A0%B1
# [log] 外部連結: [中華人民共和國] /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD
# [log] 外部連結: [沙烏地阿拉伯] /wiki/%E6%B2%99%E7%89%B9%E9%98%BF%E6%8B%89%E4%BC%AF
# [log] 外部連結: [政治] /wiki/%E6%94%BF%E6%B2%BB
# [log] 外部連結: [宗教] /wiki/%E5%AE%97%E6%95%99
# [log] 外部連結: [資訊科技] /wiki/%E4%BF%A1%E6%81%AF%E6%8A%80%E6%9C%AF
# [log] 外部連結: [朝鮮] /wiki/%E6%9C%9D%E9%B2%9C
# [log] 外部連結: [國家區域網路] /wiki/%E5%9C%8B%E5%AE%B6%E5%8D%80%E5%9F%9F%E7%B6%B2%E8%B7%AF
# [log] 外部連結: [經濟合作發展組織] /wiki/%E7%B6%93%E6%BF%9F%E5%90%88%E4%BD%9C%E7%99%BC%E5%B1%95%E7%B5%84%E7%B9%94
# [log] 外部連結: [冰島] /wiki/%E5%86%B0%E5%B3%B6
# [log] 外部連結: [韓國] /wiki/%E9%9F%A9%E5%9B%BD
# [log] 外部連結: [荷蘭] /wiki/%E8%8D%B7%E8%98%AD
# [log] 外部連結: [丹麥] /wiki/%E4%B8%B9%E9%BA%A5
# [log] 外部連結: [瑞士] /wiki/%E7%91%9E%E5%A3%AB
# [log] 外部連結: [美國] /wiki/%E7%BE%8E%E5%9C%8B
# [log] 外部連結: [中國互聯網絡信息中心] /wiki/%E4%B8%AD%E5%9B%BD%E4%BA%92%E8%81%94%E7%BD%91%E7%BB%9C%E4%BF%A1%E6%81%AF%E4%B8%AD%E5%BF%83
# [log] 外部連結: [網友] /wiki/%E7%BD%91%E6%B0%91
# [log][1] new ext: 118
# 遞迴層[1] - /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8 (伺服器)
# [log] write  WikiArticl/伺服器.txt
# [log] 外部連結: [區域網路] /wiki/Intranet
# [log] 外部連結: [廣域網路] /wiki/Internet
# [log] 外部連結: [對稱多處理] /wiki/%E5%AF%B9%E7%A7%B0%E5%A4%9A%E5%A4%84%E7%90%86
# [log] 外部連結: [數據機] /wiki/%E8%B0%83%E5%88%B6%E8%A7%A3%E8%B0%83%E5%99%A8
# [log] 外部連結: [網頁伺服器] /wiki/%E7%BD%91%E9%A1%B5%E6%9C%8D%E5%8A%A1%E5%99%A8
# [log] 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# [log] 外部連結: [Apache] /wiki/Apache
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8
# [log] 外部連結: [硬體] /wiki/%E7%A1%AC%E4%BB%B6
# [log] 外部連結: [PC] /wiki/PC
# [log] 外部連結: [PC] /wiki/PC
# [log] 外部連結: [終端] /wiki/%E7%B5%82%E7%AB%AF
# [log] 外部連結: [客戶端] /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF
# [log] 外部連結: [個人電腦] /wiki/%E5%80%8B%E4%BA%BA%E9%9B%BB%E8%85%A6
# [log] 外部連結: [RAS] /wiki/%E5%8F%AF%E9%9D%A0%E6%80%A7%E3%80%81%E5%8F%AF%E7%94%A8%E6%80%A7%E5%92%8C%E5%8F%AF%E7%B6%AD%E8%AD%B7%E6%80%A7
# [log] 外部連結: [作業系統] /wiki/%E6%93%8D%E4%BD%9C%E7%B3%BB%E7%BB%9F
# [log] 外部連結: [類Unix] /wiki/%E7%B1%BBUnix
# [log] 外部連結: [Unix] /wiki/Unix
# [log] 外部連結: [類Unix] /wiki/%E7%B1%BBUnix
# [log] 外部連結: [Linux發行版] /wiki/Linux%E5%8F%91%E8%A1%8C%E7%89%88
# [log] 外部連結: [紅帽企業Linux] /wiki/Red_Hat_Enterprise_Linux
# [log] 外部連結: [SUSE] /wiki/SUSE
# [log] 外部連結: [AIX] /wiki/AIX
# [log] 外部連結: [HP-UX] /wiki/HP-UX
# [log] 外部連結: [IRIX] /wiki/IRIX
# [log] 外部連結: [FreeBSD] /wiki/FreeBSD
# [log] 外部連結: [Solaris] /wiki/Solaris
# [log] 外部連結: [Mac OS X Server] /wiki/Mac_OS_X
# [log] 外部連結: [OpenBSD] /wiki/OpenBSD
# [log] 外部連結: [NetBSD] /wiki/NetBSD
# [log] 外部連結: [微軟] /wiki/%E5%BE%AE%E8%BD%AF
# [log] 外部連結: [Microsoft Windows] /wiki/Microsoft_Windows
# [log] 外部連結: [Windows NT 4.0 Server] /wiki/Windows_NT_4.0
# [log] 外部連結: [Windows 2000 Server] /wiki/Windows_2000_Server
# [log] 外部連結: [Windows Server 2003] /wiki/Windows_Server_2003
# [log] 外部連結: [Windows Server 2008] /wiki/Windows_Server_2008
# [log] 外部連結: [Windows Server 2008 R2] /wiki/Windows_Server_2008_R2
# [log] 外部連結: [Windows Server 2012] /wiki/Windows_Server_2012
# [log] 外部連結: [Windows Server 2012 R2] /wiki/Windows_Server_2012_R2
# [log] 外部連結: [Windows Server 2016] /wiki/Windows_Server_2016
# [log] 外部連結: [Windows Server 2019] /wiki/Windows_Server_2019
# [log] 外部連結: [軟體] /wiki/%E8%BD%AF%E4%BB%B6
# [log] 外部連結: [客戶端-伺服器] /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF-%E6%9C%8D%E5%8A%A1%E5%99%A8
# [log] 外部連結: [瀏覽器-伺服器] /wiki/%E6%B5%8F%E8%A7%88%E5%99%A8-%E6%9C%8D%E5%8A%A1%E5%99%A8
# [log] 外部連結: [刀鋒伺服器] /wiki/%E5%88%80%E9%8B%92%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log][1] new ext: 43
# 遞迴層[1] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A (超文字傳輸協定)
# [log] write  WikiArticl/超文字傳輸協定.txt
# [log] 外部連結: [超媒體] /wiki/%E8%B6%85%E5%AA%92%E9%AB%94
# [log] 外部連結: [應用層] /wiki/%E5%BA%94%E7%94%A8%E5%B1%82
# [log] 外部連結: [協定] /wiki/%E7%BD%91%E7%BB%9C%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [全球資訊網] /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2
# [log] 外部連結: [HTML] /wiki/HTML
# [log] 外部連結: [HTTPS] /wiki/HTTPS
# [log] 外部連結: [統一資源識別碼] /wiki/%E7%BB%9F%E4%B8%80%E8%B5%84%E6%BA%90%E6%A0%87%E5%BF%97%E7%AC%A6
# [log] 外部連結: [提姆·柏內茲-李] /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E
# [log] 外部連結: [歐洲核子研究組織] /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94
# [log] 外部連結: [全球資訊網協會] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F
# [log] 外部連結: [網際網路工程任務組] /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%B7%A5%E7%A8%8B%E4%BB%BB%E5%8A%A1%E7%BB%84
# [log] 外部連結: [RFC] /wiki/RFC
# [log] 外部連結: [網際網路工程任務組] /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%B7%A5%E7%A8%8B%E4%BB%BB%E5%8A%A1%E7%BB%84
# [log] 外部連結: [HTTP/2] /wiki/HTTP/2
# [log] 外部連結: [TCP協定] /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# [log] 外部連結: [網路爬蟲] /wiki/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB
# [log] 外部連結: [埠] /wiki/%E9%80%9A%E8%A8%8A%E5%9F%A0
# [log] 外部連結: [代理伺服器] /wiki/%E4%BB%A3%E7%90%86%E4%BC%BA%E6%9C%8D%E5%99%A8
# [log] 外部連結: [閘道器] /wiki/%E7%BD%91%E5%85%B3
# [log] 外部連結: [隧道] /wiki/%E9%9A%A7%E9%81%93
# [log] 外部連結: [TCP/IP] /wiki/TCP/IP
# [log] 外部連結: [狀態碼405] /wiki/HTTP%E7%8A%B6%E6%80%81%E7%A0%81#405
# [log] 外部連結: [狀態碼501] /wiki/HTTP%E7%8A%B6%E6%80%81%E7%A0%81#501
# [log] 外部連結: [超連結] /wiki/%E8%B6%85%E9%93%BE%E6%8E%A5
# [log] 外部連結: [冪等(idempotence)] /wiki/%E5%86%AA%E7%AD%89
# [log] 外部連結: [向下相容] /wiki/%E5%90%91%E4%B8%8B%E5%85%BC%E5%AE%B9
# [log] 外部連結: [代理伺服器] /wiki/%E4%BB%A3%E7%90%86%E6%9C%8D%E5%8A%A1%E5%99%A8
# [log] 外部連結: [[來源請求]] /wiki/Wikipedia:%E5%88%97%E6%98%8E%E6%9D%A5%E6%BA%90
# [log] 外部連結: [管道方式] /wiki/HTTP%E7%AE%A1%E7%BA%BF%E5%8C%96
# [log] 外部連結: [狀態代碼] /wiki/HTTP%E7%8A%B6%E6%80%81%E7%A0%81
# [log] 外部連結: [404 Not Found] /wiki/HTTP_404
# [log] 外部連結: [TCP連線] /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE
# [log] 外部連結: [等待時間] /wiki/%E5%BB%B6%E8%BF%9F_(%E5%B7%A5%E7%A8%8B%E5%AD%A6)
# [log] 外部連結: [TCP交握程式] /wiki/%E6%8F%A1%E6%89%8B_(%E6%8A%80%E6%9C%AF)
# [log] 外部連結: [分塊傳輸編碼] /wiki/%E5%88%86%E5%9D%97%E4%BC%A0%E8%BE%93%E7%BC%96%E7%A0%81
# [log] 外部連結: [緩衝器] /wiki/%E7%B7%A9%E8%A1%9D%E5%99%A8
# [log] 外部連結: [用戶感受到的] /wiki/%E4%BD%BF%E7%94%A8%E8%80%85%E7%B6%93%E9%A9%97
# [log] 外部連結: [Gopher] /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE)
# [log] 外部連結: [SPDY] /wiki/SPDY
# [log] 外部連結: [Google] /wiki/Google
# [log] 外部連結: [HTTP/2] /wiki/HTTP/2
# [log][1] new ext: 39
